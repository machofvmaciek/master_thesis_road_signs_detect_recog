# %% [markdown]
# ## Maciej Olszewski
#
# This is a jupyter notebook wrapper to run detect-classify traffic signs app **using cloud**.
#
# _Google Cloud Platform_ version.

# %%
import os
import cv2
import json
import requests

import matplotlib.pyplot as plt
import numpy as np

from detect import Detector, NoDetectionsException

# %%
from datetime import datetime
# DIR_TEST_IMAGES = "/Users/machofv/Downloads/GTSDB-archive-2/TrainIJCNN2013/TrainIJCNN2013"
DIR_TEST_IMAGES = "/Users/machofv/Downloads/GTSDB-archive-2/TestIJCNN2013/TestIJCNN2013Download"

DIR_RESULTS = f"{os.path.abspath('')}/../results/{datetime.today()}"

HTTP_FUNCTION = "https://europe-central2-aesthetic-fiber-428811-m0.cloudfunctions.net/rs-recognize"

# %%
def __img_to_json(img: np.ndarray) -> dict:
    """Jsonifies given array."""
    # return json.dumps(img.tolist())
    return {"ndarray_data": json.dumps(img.tolist())}

def __send_request(message: dict, url: str):
    response = requests.post(url, json=message)
    if response.status_code == 200:
        # print("response:", response.text)

        response_dict = json.loads(response.text)

        return response_dict.get("prediction", "")
    else:
        print(f"Error: {response.status_code}, {response.text}")
        raise Exception(f"Error: {response.status_code}, {response.text}")

# %%
def enhance_contrast_adaptive(img, clip_limit=2.0, tile_grid_size=(8, 8)):
    img_yuv = cv2.cvtColor(img, cv2.COLOR_BGR2YUV)
    clahe = cv2.createCLAHE(clipLimit=clip_limit, tileGridSize=tile_grid_size)
    img_yuv[:, :, 0] = clahe.apply(img_yuv[:, :, 0])  # Apply CLAHE to the Y (luminance) channel
    img_enhanced = cv2.cvtColor(img_yuv, cv2.COLOR_YUV2BGR)
    return img_enhanced

def visualize(img, imgs_detected, predictions, j_counter, is_saved=False):
    plt.subplots_adjust(top=0.90)
    fig, axs = plt.subplots(1, 1+len(predictions), figsize=(15, 5))

    axs[0].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    axs[0].set_title('Original image')
    axs[0].axis('off')

    for i, img_disp in enumerate(imgs_detected):
        axs[i+1].imshow(cv2.cvtColor(img_disp, cv2.COLOR_BGR2RGB))
        axs[i+1].set_title(predictions[i])
        axs[i+1].axis("off")
    plt.tight_layout()
    if is_saved:
        plt.savefig(f"{DIR_RESULTS}/result_{j_counter}")
    else:
        plt.show()

def visualize_enhanced(img, imgs_detected, imgs_enhanced, predictions, j_counter, is_saved=False):
    plt.subplots_adjust(top=0.90)
    fig, axs = plt.subplots(2, 1+len(predictions), figsize=(15, 5))

    axs[0][0].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    axs[0][0].set_title('Original image')
    axs[0][0].axis('off')
    axs[1][0].axis("off")

    for i, img_disp in enumerate(imgs_detected):
        axs[0][i+1].imshow(cv2.cvtColor(img_disp, cv2.COLOR_BGR2RGB))
        axs[0][i+1].set_title(predictions[i])
        axs[0][i+1].axis("off")

        axs[1][i+1].imshow(cv2.cvtColor(imgs_enhanced[i], cv2.COLOR_BGR2RGB))
        axs[1][i+1].set_title("(inc. contrast)")
        axs[1][i+1].axis("off")

    plt.tight_layout()
    if is_saved:
        plt.savefig(f"{DIR_RESULTS}/result_{j_counter}")
    else:
        plt.show()

# %%
def run_from_folder(DIR_IMAGES, detector, URL, is_enhanced=True, is_saved=False):
    test_imgs = os.listdir(DIR_IMAGES)
    for j, IMG_PATH in enumerate(test_imgs):

        imgs_detected = []
        if IMG_PATH == ".DS_Store":
            continue
        try:
            imgs_detected = detector.detect_yolo(f"{DIR_IMAGES}/{IMG_PATH}")
        except NoDetectionsException:
            continue
        except IOError:
            print(f"WARNING! - '{IMG_PATH}' file cannot be read! Skipping...")
            continue

        predictions = []
        if is_enhanced: imgs_enhanced = []

        if imgs_detected:
            for img_detected in imgs_detected:

                if is_enhanced:
                    # img_enhanced = cv2.convertScaleAbs(img_detected, alpha=1.5, beta=15)
                    img_enhanced = enhance_contrast_adaptive(img_detected)
                    imgs_enhanced.append(img_enhanced)
                    img_resized = np.expand_dims(cv2.resize(img_enhanced, (64, 64)), axis=0)
                    message_json = __img_to_json(img_resized)

                else:
                    img_resized = np.expand_dims(cv2.resize(img_detected, (64, 64)), axis=0)
                    message_json = __img_to_json(img_resized)                
                
                response = __send_request(message_json, URL)
                predictions.append(response)

                
            NUM_OF_PREDS = len(predictions)
            img = cv2.imread(f"{DIR_IMAGES}/{IMG_PATH}")

            # Visualize the data
            if is_enhanced:
                visualize_enhanced(img, imgs_detected, imgs_enhanced, predictions, j, is_saved=is_saved)
            else:
                visualize(img, imgs_detected, predictions, j, is_saved=is_saved)

# %%
detector = Detector()

# %%
os.makedirs(DIR_RESULTS, exist_ok=True)

run_from_folder(DIR_TEST_IMAGES, detector, HTTP_FUNCTION, is_enhanced=True, is_saved=True)
# Out:
# 0: 384x640 1 Traffic sign, 16.9ms
# Speed: 2.1ms preprocess, 16.9ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.9ms
# Speed: 2.4ms preprocess, 24.9ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 21.9ms
# Speed: 2.0ms preprocess, 21.9ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 21.6ms
# Speed: 1.9ms preprocess, 21.6ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 Traffic signs, 18.3ms
# Speed: 1.8ms preprocess, 18.3ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.6ms
# Speed: 2.1ms preprocess, 18.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 18.7ms
# Speed: 2.2ms preprocess, 18.7ms inference, 65.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 24.1ms
# Speed: 2.1ms preprocess, 24.1ms inference, 50.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 22.5ms
# Speed: 2.1ms preprocess, 22.5ms inference, 51.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Traffic signs, 20.6ms
# Speed: 1.8ms preprocess, 20.6ms inference, 23.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 Traffic signs, 19.0ms
# Speed: 1.7ms preprocess, 19.0ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 18.8ms
# Speed: 1.7ms preprocess, 18.8ms inference, 46.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 18.8ms
# Speed: 2.0ms preprocess, 18.8ms inference, 48.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Traffic signs, 17.5ms
# Speed: 1.7ms preprocess, 17.5ms inference, 23.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 18.3ms
# Speed: 1.7ms preprocess, 18.3ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Traffic signs, 18.6ms
# Speed: 2.0ms preprocess, 18.6ms inference, 59.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 17.9ms
# Speed: 2.2ms preprocess, 17.9ms inference, 46.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 18.4ms
# Speed: 2.1ms preprocess, 18.4ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 18.4ms
# Speed: 1.8ms preprocess, 18.4ms inference, 50.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.8ms
# Speed: 1.8ms preprocess, 18.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 20.9ms
# Speed: 1.8ms preprocess, 20.9ms inference, 55.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 Traffic signs, 23.8ms
# Speed: 1.8ms preprocess, 23.8ms inference, 70.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 17.9ms
# Speed: 2.1ms preprocess, 17.9ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.3ms
# Speed: 2.0ms preprocess, 18.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Traffic signs, 18.2ms
# Speed: 2.7ms preprocess, 18.2ms inference, 47.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 Traffic signs, 19.6ms
# Speed: 1.8ms preprocess, 19.6ms inference, 81.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Traffic signs, 24.5ms
# Speed: 1.8ms preprocess, 24.5ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 21.7ms
# Speed: 1.6ms preprocess, 21.7ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
# /var/folders/v3/vkc53k7s67jd8p8llsp_2czh0000gn/T/ipykernel_66708/1824003793.py:28: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, axs = plt.subplots(2, 1+len(predictions), figsize=(15, 5))
# 0: 384x640 (no detections), 19.3ms
# Speed: 2.0ms preprocess, 19.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 17.6ms
# Speed: 1.8ms preprocess, 17.6ms inference, 47.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 26.4ms
# Speed: 1.9ms preprocess, 26.4ms inference, 11.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 21.4ms
# Speed: 1.8ms preprocess, 21.4ms inference, 48.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 17.9ms
# Speed: 2.0ms preprocess, 17.9ms inference, 11.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Traffic signs, 17.8ms
# Speed: 1.8ms preprocess, 17.8ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 19.1ms
# Speed: 1.9ms preprocess, 19.1ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Traffic signs, 18.2ms
# Speed: 1.7ms preprocess, 18.2ms inference, 47.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 Traffic signs, 17.9ms
# Speed: 2.1ms preprocess, 17.9ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.6ms
# Speed: 2.3ms preprocess, 17.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 17.3ms
# Speed: 1.8ms preprocess, 17.3ms inference, 46.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 17.9ms
# Speed: 1.9ms preprocess, 17.9ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Traffic signs, 17.8ms
# Speed: 1.9ms preprocess, 17.8ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Traffic signs, 17.5ms
# Speed: 1.8ms preprocess, 17.5ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Traffic signs, 19.4ms
# Speed: 1.8ms preprocess, 19.4ms inference, 46.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 18.5ms
# Speed: 1.9ms preprocess, 18.5ms inference, 47.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Traffic signs, 17.8ms
# Speed: 1.7ms preprocess, 17.8ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 Traffic signs, 18.3ms
# Speed: 1.7ms preprocess, 18.3ms inference, 45.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.4ms
# Speed: 3.2ms preprocess, 27.4ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 Traffic signs, 18.7ms
# Speed: 2.3ms preprocess, 18.7ms inference, 67.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 31.7ms
# Speed: 2.5ms preprocess, 31.7ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 20.8ms
# Speed: 1.9ms preprocess, 20.8ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Traffic signs, 17.5ms
# Speed: 1.9ms preprocess, 17.5ms inference, 62.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 18.7ms
# Speed: 1.7ms preprocess, 18.7ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 18.7ms
# Speed: 2.4ms preprocess, 18.7ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 23.8ms
# Speed: 3.0ms preprocess, 23.8ms inference, 22.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 23.7ms
# Speed: 2.1ms preprocess, 23.7ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 23.7ms
# Speed: 2.6ms preprocess, 23.7ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Traffic signs, 18.9ms
# Speed: 1.7ms preprocess, 18.9ms inference, 64.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 24.6ms
# Speed: 2.2ms preprocess, 24.6ms inference, 69.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 17.5ms
# Speed: 2.0ms preprocess, 17.5ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 23.2ms
# Speed: 2.0ms preprocess, 23.2ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.7ms
# Speed: 1.9ms preprocess, 18.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 19.3ms
# Speed: 1.8ms preprocess, 19.3ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 Traffic signs, 19.1ms
# Speed: 2.0ms preprocess, 19.1ms inference, 15.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 23.3ms
# Speed: 1.7ms preprocess, 23.3ms inference, 19.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Traffic signs, 20.8ms
# Speed: 2.0ms preprocess, 20.8ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 21.1ms
# Speed: 2.1ms preprocess, 21.1ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 20.4ms
# Speed: 2.0ms preprocess, 20.4ms inference, 71.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.4ms
# Speed: 1.9ms preprocess, 23.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Traffic signs, 19.9ms
# Speed: 1.7ms preprocess, 19.9ms inference, 16.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 21.0ms
# Speed: 1.7ms preprocess, 21.0ms inference, 15.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.5ms
# Speed: 2.1ms preprocess, 17.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 17.4ms
# Speed: 1.9ms preprocess, 17.4ms inference, 70.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 25.2ms
# Speed: 2.2ms preprocess, 25.2ms inference, 16.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Traffic signs, 18.3ms
# Speed: 1.8ms preprocess, 18.3ms inference, 62.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 21.1ms
# Speed: 2.8ms preprocess, 21.1ms inference, 16.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 22.0ms
# Speed: 4.9ms preprocess, 22.0ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 17.2ms
# Speed: 1.9ms preprocess, 17.2ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 29.4ms
# Speed: 2.1ms preprocess, 29.4ms inference, 33.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.6ms
# Speed: 2.7ms preprocess, 18.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 Traffic signs, 20.4ms
# Speed: 2.1ms preprocess, 20.4ms inference, 15.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 20.8ms
# Speed: 1.9ms preprocess, 20.8ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 17.6ms
# Speed: 1.8ms preprocess, 17.6ms inference, 12.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Traffic signs, 20.1ms
# Speed: 1.9ms preprocess, 20.1ms inference, 64.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 17.4ms
# Speed: 1.6ms preprocess, 17.4ms inference, 60.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 20.3ms
# Speed: 1.7ms preprocess, 20.3ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 21.8ms
# Speed: 2.6ms preprocess, 21.8ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 19.0ms
# Speed: 1.9ms preprocess, 19.0ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 39.5ms
# Speed: 2.3ms preprocess, 39.5ms inference, 12.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 Traffic signs, 22.5ms
# Speed: 3.5ms preprocess, 22.5ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 22.1ms
# Speed: 2.1ms preprocess, 22.1ms inference, 20.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.1ms
# Speed: 1.9ms preprocess, 19.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 23.1ms
# Speed: 1.7ms preprocess, 23.1ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 23.2ms
# Speed: 2.0ms preprocess, 23.2ms inference, 75.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 22.1ms
# Speed: 2.0ms preprocess, 22.1ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 22.5ms
# Speed: 2.0ms preprocess, 22.5ms inference, 16.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Traffic signs, 19.4ms
# Speed: 1.9ms preprocess, 19.4ms inference, 65.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 20.6ms
# Speed: 2.8ms preprocess, 20.6ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 18.9ms
# Speed: 2.2ms preprocess, 18.9ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 21.7ms
# Speed: 2.4ms preprocess, 21.7ms inference, 16.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.1ms
# Speed: 1.8ms preprocess, 19.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 17.9ms
# Speed: 2.1ms preprocess, 17.9ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 21.1ms
# Speed: 2.2ms preprocess, 21.1ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Traffic signs, 19.3ms
# Speed: 1.7ms preprocess, 19.3ms inference, 10.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Traffic signs, 18.9ms
# Speed: 1.7ms preprocess, 18.9ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 17.7ms
# Speed: 2.0ms preprocess, 17.7ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Traffic signs, 19.4ms
# Speed: 2.2ms preprocess, 19.4ms inference, 75.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 17.8ms
# Speed: 1.7ms preprocess, 17.8ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.9ms
# Speed: 1.9ms preprocess, 17.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 18.3ms
# Speed: 1.7ms preprocess, 18.3ms inference, 14.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.4ms
# Speed: 2.2ms preprocess, 20.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Traffic signs, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 Traffic signs, 17.8ms
# Speed: 1.7ms preprocess, 17.8ms inference, 13.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 17.8ms
# Speed: 1.9ms preprocess, 17.8ms inference, 13.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 18.7ms
# Speed: 1.7ms preprocess, 18.7ms inference, 15.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 17.8ms
# Speed: 1.8ms preprocess, 17.8ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 21.3ms
# Speed: 1.8ms preprocess, 21.3ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 23.7ms
# Speed: 2.0ms preprocess, 23.7ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 19.3ms
# Speed: 1.6ms preprocess, 19.3ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 17.6ms
# Speed: 1.8ms preprocess, 17.6ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 17.3ms
# Speed: 1.8ms preprocess, 17.3ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 20.1ms
# Speed: 1.7ms preprocess, 20.1ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 19.6ms
# Speed: 1.9ms preprocess, 19.6ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 Traffic signs, 30.1ms
# Speed: 3.3ms preprocess, 30.1ms inference, 20.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Traffic signs, 18.1ms
# Speed: 1.8ms preprocess, 18.1ms inference, 66.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 Traffic signs, 20.6ms
# Speed: 2.0ms preprocess, 20.6ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 17.9ms
# Speed: 1.5ms preprocess, 17.9ms inference, 14.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 17.7ms
# Speed: 1.6ms preprocess, 17.7ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 18.3ms
# Speed: 2.5ms preprocess, 18.3ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.0ms
# Speed: 2.1ms preprocess, 18.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 18.7ms
# Speed: 1.8ms preprocess, 18.7ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Traffic signs, 20.9ms
# Speed: 2.2ms preprocess, 20.9ms inference, 27.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 18.8ms
# Speed: 2.5ms preprocess, 18.8ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 19.7ms
# Speed: 1.9ms preprocess, 19.7ms inference, 14.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 17.4ms
# Speed: 2.1ms preprocess, 17.4ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.0ms
# Speed: 2.1ms preprocess, 18.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 18.4ms
# Speed: 1.8ms preprocess, 18.4ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 17.6ms
# Speed: 2.0ms preprocess, 17.6ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 17.8ms
# Speed: 2.3ms preprocess, 17.8ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 18.2ms
# Speed: 1.6ms preprocess, 18.2ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 18.4ms
# Speed: 2.4ms preprocess, 18.4ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 18.1ms
# Speed: 1.8ms preprocess, 18.1ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 19.1ms
# Speed: 1.6ms preprocess, 19.1ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 18.7ms
# Speed: 2.0ms preprocess, 18.7ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 18.7ms
# Speed: 1.7ms preprocess, 18.7ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Traffic signs, 19.0ms
# Speed: 2.0ms preprocess, 19.0ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 17.5ms
# Speed: 1.8ms preprocess, 17.5ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 17.8ms
# Speed: 2.0ms preprocess, 17.8ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Traffic signs, 17.3ms
# Speed: 1.7ms preprocess, 17.3ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Traffic signs, 18.8ms
# Speed: 1.8ms preprocess, 18.8ms inference, 14.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.9ms
# Speed: 1.8ms preprocess, 17.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 17.7ms
# Speed: 2.2ms preprocess, 17.7ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 18.4ms
# Speed: 2.1ms preprocess, 18.4ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.0ms
# Speed: 1.8ms preprocess, 19.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.8ms
# Speed: 1.8ms preprocess, 17.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Traffic signs, 18.3ms
# Speed: 2.0ms preprocess, 18.3ms inference, 66.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 17.4ms
# Speed: 1.7ms preprocess, 17.4ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 17.3ms
# Speed: 2.2ms preprocess, 17.3ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.2ms
# Speed: 2.2ms preprocess, 17.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.8ms
# Speed: 2.2ms preprocess, 19.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Traffic signs, 17.3ms
# Speed: 1.9ms preprocess, 17.3ms inference, 13.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Traffic signs, 17.7ms
# Speed: 1.9ms preprocess, 17.7ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Traffic signs, 17.8ms
# Speed: 1.6ms preprocess, 17.8ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Traffic signs, 17.7ms
# Speed: 1.7ms preprocess, 17.7ms inference, 68.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 26.8ms
# Speed: 12.3ms preprocess, 26.8ms inference, 17.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 21.6ms
# Speed: 2.3ms preprocess, 21.6ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 19.7ms
# Speed: 1.7ms preprocess, 19.7ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 19.0ms
# Speed: 1.8ms preprocess, 19.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 21.4ms
# Speed: 1.8ms preprocess, 21.4ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 Traffic signs, 17.9ms
# Speed: 1.9ms preprocess, 17.9ms inference, 35.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.0ms
# Speed: 2.3ms preprocess, 19.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 21.8ms
# Speed: 1.9ms preprocess, 21.8ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Traffic signs, 19.5ms
# Speed: 1.6ms preprocess, 19.5ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 Traffic signs, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 18.0ms
# Speed: 1.8ms preprocess, 18.0ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 18.1ms
# Speed: 1.7ms preprocess, 18.1ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.3ms
# Speed: 1.7ms preprocess, 17.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 18.4ms
# Speed: 1.9ms preprocess, 18.4ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 17.9ms
# Speed: 1.9ms preprocess, 17.9ms inference, 13.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Traffic signs, 17.8ms
# Speed: 1.9ms preprocess, 17.8ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 18.0ms
# Speed: 1.8ms preprocess, 18.0ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 17.7ms
# Speed: 2.3ms preprocess, 17.7ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 Traffic signs, 18.7ms
# Speed: 1.7ms preprocess, 18.7ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 18.5ms
# Speed: 1.7ms preprocess, 18.5ms inference, 92.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 21.3ms
# Speed: 1.7ms preprocess, 21.3ms inference, 33.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 22.0ms
# Speed: 2.1ms preprocess, 22.0ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 17.3ms
# Speed: 2.7ms preprocess, 17.3ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 19.4ms
# Speed: 1.7ms preprocess, 19.4ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.8ms
# Speed: 2.3ms preprocess, 24.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 17.3ms
# Speed: 1.8ms preprocess, 17.3ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Traffic signs, 18.5ms
# Speed: 1.7ms preprocess, 18.5ms inference, 13.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 17.7ms
# Speed: 1.8ms preprocess, 17.7ms inference, 13.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 17.7ms
# Speed: 2.4ms preprocess, 17.7ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 17.9ms
# Speed: 1.9ms preprocess, 17.9ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 19.2ms
# Speed: 2.1ms preprocess, 19.2ms inference, 13.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 17.9ms
# Speed: 1.9ms preprocess, 17.9ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Traffic signs, 18.1ms
# Speed: 1.9ms preprocess, 18.1ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 18.2ms
# Speed: 2.3ms preprocess, 18.2ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Traffic signs, 17.4ms
# Speed: 2.0ms preprocess, 17.4ms inference, 15.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 17.5ms
# Speed: 2.0ms preprocess, 17.5ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Traffic signs, 22.4ms
# Speed: 1.8ms preprocess, 22.4ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 Traffic signs, 18.5ms
# Speed: 2.1ms preprocess, 18.5ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 17.8ms
# Speed: 1.9ms preprocess, 17.8ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 18.8ms
# Speed: 2.0ms preprocess, 18.8ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.4ms
# Speed: 2.0ms preprocess, 20.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 28.8ms
# Speed: 2.2ms preprocess, 28.8ms inference, 16.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 22.3ms
# Speed: 2.7ms preprocess, 22.3ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 19.9ms
# Speed: 1.7ms preprocess, 19.9ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 19.8ms
# Speed: 2.4ms preprocess, 19.8ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.2ms
# Speed: 2.5ms preprocess, 23.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Traffic signs, 17.9ms
# Speed: 2.0ms preprocess, 17.9ms inference, 12.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 21.7ms
# Speed: 1.9ms preprocess, 21.7ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 22.8ms
# Speed: 2.1ms preprocess, 22.8ms inference, 10.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 18.3ms
# Speed: 1.9ms preprocess, 18.3ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 17.9ms
# Speed: 1.9ms preprocess, 17.9ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.3ms
# Speed: 2.1ms preprocess, 17.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.7ms
# Speed: 1.9ms preprocess, 19.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 18.1ms
# Speed: 1.9ms preprocess, 18.1ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 17.5ms
# Speed: 1.7ms preprocess, 17.5ms inference, 15.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 19.3ms
# Speed: 2.8ms preprocess, 19.3ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Traffic signs, 16.9ms
# Speed: 1.8ms preprocess, 16.9ms inference, 63.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 18.3ms
# Speed: 1.7ms preprocess, 18.3ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Traffic sign, 18.5ms
# Speed: 2.7ms preprocess, 18.5ms inference, 13.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 Traffic signs, 25.4ms
# Speed: 1.8ms preprocess, 25.4ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Traffic signs, 42.3ms
# Speed: 3.8ms preprocess, 42.3ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Traffic signs, 20.7ms
# Speed: 1.7ms preprocess, 20.7ms inference, 18.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Traffic signs, 18.0ms
# Speed: 1.9ms preprocess, 18.0ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
